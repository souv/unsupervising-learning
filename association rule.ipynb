# %%
dataset = [['milk','onion','nutmeg','kidney beans','eggs','yogurt'],
           ['dill','onion','nutmeg','kidney beans','eggs','yogurt'],
           ['milk','apple','kidney beans','eggs'],
           ['milk','unicorn','corn','kidney beans','yogurt'],
           ['corn','onion','onion','kidney beans','ice cream','eggs']]

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

# %%
dataset
# Out:
# [['milk', 'onion', 'nutmeg', 'kidney beans', 'eggs', 'yogurt'],
#  ['dill', 'onion', 'nutmeg', 'kidney beans', 'eggs', 'yogurt'],
#  ['milk', 'apple', 'kidney beans', 'eggs'],
#  ['milk', 'unicorn', 'corn', 'kidney beans', 'yogurt'],
#  ['corn', 'onion', 'onion', 'kidney beans', 'ice cream', 'eggs']]

# %%
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)

# %%
df = pd.DataFrame(te_ary,columns = te.columns_)
df
# Out:
#    apple   corn   dill   eggs  ice cream  kidney beans   milk  nutmeg  onion  \
# 0  False  False  False   True      False          True   True    True   True
# 1  False  False   True   True      False          True  False    True   True
# 2   True  False  False   True      False          True   True   False  False
# 3  False   True  False  False      False          True   True   False  False
# 4  False   True  False   True       True          True  False   False   True
#
#    unicorn  yogurt
# 0    False    True
# 1    False    True
# 2    False   False
# 3     True    True
# 4    False   False

# %%
from mlxtend.frequent_patterns import apriori

# %%
frequent_itemsets = apriori(df,min_support=0.01,use_colnames = True)
frequent_itemsets

# %%
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets
frequent_itemsets.to_csv('frequent_itemsets.csv')

# %%
from mlxtend.frequent_patterns import association_rules
res = association_rules(frequent_itemsets,metric="confidence",min_threshold=0.7)
res
# Out:
#                antecedents                           consequents  \
# 0                  (apple)                                (eggs)
# 1                  (apple)                        (kidney beans)
# 2                  (apple)                                (milk)
# 3              (ice cream)                                (corn)
# 4                   (corn)                        (kidney beans)
# ..                     ...                                   ...
# 628    (onion, eggs, milk)        (yogurt, kidney beans, nutmeg)
# 629  (onion, nutmeg, milk)          (yogurt, kidney beans, eggs)
# 630   (nutmeg, eggs, milk)         (onion, yogurt, kidney beans)
# 631          (onion, milk)  (yogurt, kidney beans, nutmeg, eggs)
# 632         (nutmeg, milk)   (onion, yogurt, kidney beans, eggs)
#
#      antecedent support  consequent support  support  confidence      lift  \
# 0                   0.2                 0.8      0.2         1.0  1.250000
# 1                   0.2                 1.0      0.2         1.0  1.000000
# 2                   0.2                 0.6      0.2         1.0  1.666667
# 3                   0.2                 0.4      0.2         1.0  2.500000
# 4                   0.4                 1.0      0.4         1.0  1.000000
# ..                  ...                 ...      ...         ...       ...
# 628                 0.2                 0.4      0.2         1.0  2.500000
# 629                 0.2                 0.4      0.2         1.0  2.500000
# 630                 0.2                 0.4      0.2         1.0  2.500000
# 631                 0.2                 0.4      0.2         1.0  2.500000
# 632                 0.2                 0.4      0.2         1.0  2.500000
#
#      leverage  conviction
# 0        0.04         inf
# 1        0.00         inf
# 2        0.08         inf
# 3        0.12         inf
# 4        0.00         inf
# ..        ...         ...
# 628      0.12         inf
# 629      0.12         inf
# 630      0.12         inf
# 631      0.12         inf
# 632      0.12         inf
#
# [633 rows x 9 columns]

# %%
res1 = res[['antecedents','consequents','support','confidence','lift']]
res1
res1.to_csv('res1.csv')

# %%
res2 = res1[res1['confidence'] >= 1]
res2
# Out:
#               antecedents           consequents  support  confidence  lift
# 1                  (eggs)        (kidney beans)      0.8         1.0  1.00
# 2                 (onion)                (eggs)      0.6         1.0  1.25
# 4                  (milk)        (kidney beans)      0.6         1.0  1.00
# 5                 (onion)        (kidney beans)      0.6         1.0  1.00
# 6                (yogurt)        (kidney beans)      0.6         1.0  1.00
# 7   (onion, kidney beans)                (eggs)      0.6         1.0  1.25
# 8           (onion, eggs)        (kidney beans)      0.6         1.0  1.00
# 10                (onion)  (kidney beans, eggs)      0.6         1.0  1.25
